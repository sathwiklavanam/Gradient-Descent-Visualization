# %%
import numpy as np

def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 10000
    n = len(x)
    learning_rate = 0.08

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))

x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

gradient_descent(x,y)
# Out:
# m 4.96, b 1.44, cost 89.0 iteration 0
# m 0.4991999999999983, b 0.26879999999999993, cost 71.10560000000002 iteration 1
# m 4.451584000000002, b 1.426176000000001, cost 56.8297702400001 iteration 2
# m 0.892231679999997, b 0.5012275199999995, cost 45.43965675929613 iteration 3
# m 4.041314713600002, b 1.432759910400001, cost 36.35088701894832 iteration 4
# m 1.2008760606719973, b 0.7036872622079998, cost 29.097483330142282 iteration 5
# m 3.7095643080294423, b 1.4546767911321612, cost 23.307872849944438 iteration 6
# m 1.4424862661541864, b 0.881337636696883, cost 18.685758762535738 iteration 7
# m 3.4406683721083144, b 1.4879302070713722, cost 14.994867596913156 iteration 8
# m 1.6308855378034224, b 1.0383405553279617, cost 12.046787238456794 iteration 9
# m 3.2221235247119777, b 1.5293810083298451, cost 9.691269350698109 iteration 10
# m 1.7770832372205707, b 1.1780607551353204, cost 7.8084968312098315 iteration 11
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

def gradient_descent(x, y):
    m_curr = b_curr = 0
    iterations = 1000
    n = len(x)
    learning_rate = 0.08

    cost_history = []
    m_values = []
    b_values = []

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum((y - y_predicted) ** 2)
        md = -(2/n) * sum(x * (y - y_predicted))
        bd = -(2/n) * sum(y - y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd

        cost_history.append(cost)
        m_values.append(m_curr)
        b_values.append(b_curr)

        if i % 100 == 0:  # Print only every 100 iterations
            print(f"Iteration {i}: m = {m_curr:.4f}, b = {b_curr:.4f}, cost = {cost:.4f}")
    
    # Final line plot
    plt.figure(figsize=(10, 4))

    # Cost over iterations
    plt.subplot(1, 2, 1)
    plt.plot(range(iterations), cost_history, color='red')
    plt.title("Cost over Iterations")
    plt.xlabel("Iterations")
    plt.ylabel("Cost")

    # Regression line
    plt.subplot(1, 2, 2)
    plt.scatter(x, y, color='blue', label='Actual')
    plt.plot(x, m_curr * x + b_curr, color='green', label='Predicted')
    plt.title("Linear Regression Fit")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.legend()

    plt.tight_layout()
    plt.show()

# Input data
x = np.array([1, 2, 3, 4, 5])
y = np.array([5, 7, 9, 11, 13])

gradient_descent(x, y)
# Out:
# Iteration 0: m = 4.9600, b = 1.4400, cost = 89.0000
# Iteration 100: m = 2.0395, b = 2.8576, cost = 0.0039
# Iteration 200: m = 2.0025, b = 2.9908, cost = 0.0000
# Iteration 300: m = 2.0002, b = 2.9994, cost = 0.0000
# Iteration 400: m = 2.0000, b = 3.0000, cost = 0.0000
# Iteration 500: m = 2.0000, b = 3.0000, cost = 0.0000
# Iteration 600: m = 2.0000, b = 3.0000, cost = 0.0000
# Iteration 700: m = 2.0000, b = 3.0000, cost = 0.0000
# Iteration 800: m = 2.0000, b = 3.0000, cost = 0.0000
# Iteration 900: m = 2.0000, b = 3.0000, cost = 0.0000

# %%
import numpy as np
import matplotlib.pyplot as plt

def gradient_descent_visual(x, y):
    m_curr = b_curr = 0
    iterations = 200
    n = len(x)
    learning_rate = 0.08

    x_vals = np.linspace(min(x), max(x), 100)

    plt.figure(figsize=(10, 6))

    # Plot gradient descent lines
    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum((y - y_predicted) ** 2)
        md = -(2/n) * sum(x * (y - y_predicted))
        bd = -(2/n) * sum(y - y_predicted)
        m_curr -= learning_rate * md
        b_curr -= learning_rate * bd

        y_vals = m_curr * x_vals + b_curr
        plt.plot(x_vals, y_vals, color='green', alpha=0.3)  # transparent green lines

    # Scatter actual data points in red
    plt.scatter(x, y, color='red')

    plt.title("Gradient Descent Progression (Line Stack)")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.grid(True)
    plt.show()

# Sample data
x = np.array([1, 2, 3, 4, 5])
y = np.array([5, 7, 9, 11, 13])

gradient_descent_visual(x, y)
